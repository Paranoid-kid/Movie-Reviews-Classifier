# %%
import pandas as pd
import numpy as np
from glob import glob

# %%
train_pos_list = []
train_neg_list = []

pos_list = ['train/pos/*.txt', 'test/pos/*.txt']
neg_list = ['train/neg/*.txt', 'test/neg/*.txt']

for pos in pos_list:
    for f in glob(pos):
        with open(f) as temp_f:
            train_pos_list.append(temp_f.read().replace('<br />',''))
series_pos = pd.Series(train_pos_list)


for neg in neg_list:
    for f in glob(neg):
        with open(f) as temp_f:
            train_neg_list.append(temp_f.read().replace('<br />',''))
series_neg = pd.Series(train_neg_list)

# %%
df_pos = pd.DataFrame(columns=['review'],data=series_pos) # all positive reviews
df_neg = pd.DataFrame(columns=['review'],data=series_neg) # all negative reviews

# %%
df_pos['label'] = [1 for i in range(0, 25000)] # add labels
df_neg['label'] = [0 for i in range(0, 25000)] # add labels
df_all_reviews = pd.concat([df_pos, df_neg]).reset_index(drop=True) # merge pos reviews & neg reviews

# %%
df_pos
# Out:
#                                                   review  label
# 0      For a movie that gets no respect there sure ar...      1
# 1      Bizarre horror movie filled with famous faces ...      1
# 2      A solid, if unremarkable film. Matthau, as Ein...      1
# 3      It's a strange feeling to sit alone in a theat...      1
# 4      You probably all already know this by now, but...      1
# 5      I saw the movie with two grown children. Altho...      1
# 6      You're using the IMDb.You've given some hefty ...      1
# 7      This was a good film with a powerful message o...      1
# 8      Made after QUARTET was, TRIO continued the qua...      1
# 9      For a mature man, to admit that he shed a tear...      1
# 10     Aileen Gonsalves, my girlfriend, is in this fi...      1
# 11     Jonathan Demme's directorial debut for Roger C...      1
# 12     When I rented this movie to watch it, I knew t...      1
# 13     It's hard to say sometimes why exactly a film ...      1
# 14     Yes, this gets the full ten stars. It's plain ...      1
# 15     Hello. This movie is.......well.......okay. Ju...      1
# 16     This is a film that was very well done. I had ...      1
# 17     A typical romp through Cheech and Chong's real...      1
# 18     OK heres what I say: The movie was excellent. ...      1
# 19     This is one of the first films I can remember,...      1
# 20     This film is worth seeing alone for Jared Harr...      1
# 21     I was 10 years old when this show was on TV. B...      1
# 22     Here's another movie that should be loaded int...      1
# 23     To all the reviewers on this page, I would hav...      1
# 24     A favourite of mine,this movie tells of two fe...      1
# 25     As Most Off You Might off Seen Star Wars: Retu...      1
# 26     I thought this movie was LOL funny. It's a fun...      1
# 27     Hood of the Living Dead had a lot to live up t...      1
# 28     Pierce Brosnan the newest but no longer James ...      1
# 29     This is one of those Film's/pilot that if you ...      1
# ...                                                  ...    ...
# 24970  Having grown up in the typing pool era and dea...      1
# 24971  Anand is one of those low-budget but well take...      1
# 24972  This movie rocked!!!! saw it at a screener a c...      1
# 24973  After all these years, of Peter O'Tool's brill...      1
# 24974  It's not difficult, after watching this film, ...      1
# 24975  This was a great 1981 film which had a great s...      1
# 24976  'The Merchant of Venice' is one of Shakespeare...      1
# 24977  Like an earlier commentor, I saw it in 1980 an...      1
# 24978  One True Thing rises above its potentially sch...      1
# 49974  After seeing the TV commercials for this film ...      0
# 49975  Why is it that such "romantic" movies that nev...      0
# 49976  Well, here we have a zombie movie that perhaps...      0
# 49977  The horrific production doesn't qualify as a "...      0
# 49978  I agree that this film is too pretentious, and...      0
# 49979  On one Thursday evening at 10:00pm, my local w...      0
# 49980  A dark, yet humorous tale involving a cop who ...      0
# 49981  Okay, I'm sorry to the cast and crew for this ...      0
# 49982  So many bad reviewers, it made me wonder, what...      0
# 49983  This show lasted for most of the 1980s, and ha...      0
# 49984  Movie based on Jacqueline Susann's best-sellin...      0
# 49985  Pauline Kael gave this movie a good review but...      0
# 49986  There must have been a lot of background info ...      0
# 49987  This is the worst movie I have seen to date. 8...      0
# 49988  My friends and I rented this movie mistaking i...      0
# 49989  I am a huge Randolph Scott fan, so I was surpr...      0
# 49990  Loving the Andersen fairy tails as a child and...      0
# 49991  Like a lot of people, I loved the original; "A...      0
# 49992  I won't lie, I rented this film because it was...      0
# 49993  This movie should have been called "The Eyes o...      0
# 49994  There are places for political commentary in f...      0
# 49995  With actors like Depardieu and Richard it is r...      0
# 49996  If you like to get a couple of fleeting glimps...      0
# 49997  When something can be anything you want it to ...      0
# 49998  I had heard good things about "States of Grace...      0
# 49999  Well, this movie actually did have one redeemi...      0
#
# [50000 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X = df_all_reviews['review']
y = df_all_reviews['label']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0, stratify=y)

# %%
print(y_train.mean(), y_test.mean()) #  the ratio of positive to negative reviews is 1:1
# Out:
# 0.5 0.5

# %% [markdown]
# # Using sklearn

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
# Vectorizer: CountVectorizer
# Model: MultinomialNB
# Grams: 1

clf_count = Pipeline([                 
    ('vec', CountVectorizer()),  
    ('nb', MultinomialNB())      
])
clf_count.fit(X_train, y_train)   
y_pred = clf_count.predict(X_test)
print(classification_report(y_test, y_pred))
print('Accuracy: ',accuracy_score(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.83      0.88      0.85      7500
#           1       0.87      0.82      0.84      7500
#
# avg / total       0.85      0.85      0.85     15000
#
# Accuracy:  0.8468666666666667

# %%
# Vectorizer: TfidfVectorizer
# Model: MultinomialNB
# Grams: 1

clf_tf = Pipeline([                 
    ('vec', TfidfVectorizer()),  
    ('nb', MultinomialNB())      
])
clf_tf.fit(X_train, y_train)   
y_pred = clf_tf.predict(X_test)
print(classification_report(y_test, y_pred))
print('Accuracy: ',accuracy_score(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.85      0.89      0.87      7500
#           1       0.88      0.84      0.86      7500
#
# avg / total       0.87      0.87      0.87     15000
#
# Accuracy:  0.8654666666666667

# %%
# Vectorizer: CountVectorizer
# Model: LogisticRegression
# Grams: 1

clf_lr_count = Pipeline([                 
    ('vec', CountVectorizer()),  
    ('lr', LogisticRegression())      
])
clf_lr_count.fit(X_train, y_train)   
y_pred = clf_lr_count.predict(X_test)
print(classification_report(y_test, y_pred))
print('Accuracy: ',accuracy_score(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.90      0.88      0.89      7500
#           1       0.88      0.90      0.89      7500
#
# avg / total       0.89      0.89      0.89     15000
#
# Accuracy:  0.8914

# %%
# Vectorizer: TfidfVectorizer
# Model: LogisticRegression
# Grams: 1

clf_lr_tf = Pipeline([                 
    ('vec', TfidfVectorizer()),  
    ('lr', LogisticRegression())      
])
clf_lr_tf.fit(X_train, y_train)   
y_pred = clf_lr_tf.predict(X_test)
print(classification_report(y_test, y_pred))
print('Accuracy: ',accuracy_score(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.91      0.89      0.90      7500
#           1       0.89      0.91      0.90      7500
#
# avg / total       0.90      0.90      0.90     15000
#
# Accuracy:  0.8978666666666667

# %%
# Vectorizer: CountVectorizer
# Model: MultinomialNB
# Grams: 2

clf_count_bigram = Pipeline([                 
    ('vec', CountVectorizer(ngram_range=(1, 2))),  
    ('nb', MultinomialNB())
])
clf_count_bigram.fit(X_train, y_train)   
y_pred = clf_count_bigram.predict(X_test)
print(classification_report(y_test, y_pred))
print('Accuracy: ',accuracy_score(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.87      0.90      0.88      7500
#           1       0.89      0.87      0.88      7500
#
# avg / total       0.88      0.88      0.88     15000
#
# Accuracy:  0.8816

# %%
# Vectorizer: TfidfVectorizer
# Model: MultinomialNB
# Grams: 2

clf_tf_bigram = Pipeline([                 
    ('vec', TfidfVectorizer(ngram_range=(1, 2))),  
    ('nb', MultinomialNB())      
])
clf_tf_bigram.fit(X_train, y_train)   
y_pred = clf_tf_bigram.predict(X_test)
print(classification_report(y_test, y_pred))
print('Accuracy: ',accuracy_score(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.85      0.89      0.87      7500
#           1       0.88      0.84      0.86      7500
#
# avg / total       0.87      0.87      0.87     15000
#
# Accuracy:  0.8654666666666667

# %%
# Vectorizer: CountVectorizer
# Model: LogisticRegression
# Grams: 2

clf_lr_count_bigram = Pipeline([                 
    ('vec', CountVectorizer(ngram_range=(1, 2))),  
    ('lr', LogisticRegression())      
])
clf_lr_count_bigram.fit(X_train, y_train)   
y_pred = clf_lr_count_bigram.predict(X_test)
print(classification_report(y_test, y_pred))
print('Accuracy: ',accuracy_score(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.92      0.90      0.91      7500
#           1       0.90      0.92      0.91      7500
#
# avg / total       0.91      0.91      0.91     15000
#
# Accuracy:  0.9102666666666667

# %%
# Vectorizer: TfidfVectorizer
# Model: LogisticRegression
# Grams: 2

clf_lr_tf_bigram = Pipeline([                 
    ('vec', TfidfVectorizer(ngram_range=(1, 2))),  
    ('lr', LogisticRegression())      
])
clf_lr_tf_bigram.fit(X_train, y_train)   
y_pred = clf_lr_tf_bigram.predict(X_test)
print(classification_report(y_test, y_pred))
print('Accuracy: ',accuracy_score(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.91      0.89      0.90      7500
#           1       0.89      0.91      0.90      7500
#
# avg / total       0.90      0.90      0.90     15000
#
# Accuracy:  0.8978666666666667

# %%
import pickle

# The model useing following parameters has the highest score.
# Vectorizer: CountVectorizer
# Model: LogisticRegression
# Grams: 2

with open('model.pkl','wb') as f:
    pickle.dump(clf_lr_count_bigram, f)

# %%
with open('model.pkl','rb') as f:
    model_sklearn = pickle.load(f)

# %%
model_sklearn.predict_proba(['This is a good movie.'])
# Out:
# array([[0.22564186, 0.77435814]])

# %% [markdown]
# # Using fastText

# %%
df_fast_train = pd.DataFrame({'label':y_train, 'review':X_train})
df_fast_train = df_fast_train.replace(1,'__label__positive')
df_fast_train = df_fast_train.replace(0,'__label__negative')

# %%
df_fast_train
# Out:
#                    label                                             review
# 11978  __label__positive  Before there was Crash, there was this interes...
# 1532   __label__positive  In the mid-1930s Hollywood was regaining its c...
# 25683  __label__negative  I have a piece of advice for the people who ma...
# 45025  __label__negative  First the premise stinks...little boy likes to...
# 2700   __label__positive  This is a so called 'feel-good' movies, howeve...
# 23118  __label__positive  The best so-bad-it's-good movie ever made. Rud...
# 40091  __label__negative  Acting 10, Script 1. "Hurlyburly" is from that...
# 9550   __label__positive  This film is more about how children make sens...
# 11581  __label__positive  Wow, it's been years since I last saw this mov...
# 229    __label__positive  We fans of Ed Wood tend to be an obsessive bun...
# 36306  __label__negative  First, I realize that a "1" rating is supposed...
# 18769  __label__positive  "The Falcon & the Snowman" offers some of the ...
# 2976   __label__positive  "La Maman et la putain" is the beautifulest fi...
# 44736  __label__negative  Was this supposed to be a comedy? The black ca...
# 4669   __label__positive  I loved the episode but seems to me there shou...
# 25749  __label__negative  This movie is like the thousand "cat and mouse...
# 22215  __label__positive  If you only see one Ernest movie in your life,...
# 16027  __label__positive  Apparently this Australian film based on Nevil...
# 12903  __label__positive  I just want To say that this movie was excelle...
# 33898  __label__negative  OK, If you're looking for another Bastketball ...
# 28890  __label__negative  The Second Renaissance, part 1 let's us show h...
# 46709  __label__negative  Team Spirit is maybe made by the best intentio...
# 17819  __label__positive  Was excited at the opening to hear part of "Ch...
# 41152  __label__negative  This movie is stupid, made by stupid people. T...
# 44500  __label__negative  This movie had such a good premise to start wi...
# 19032  __label__positive  Joline (Heather Graham) married Carl (Luke Wil...
# 25407  __label__negative  The tragedy is that this piece of rubbish was ...
# 44728  __label__negative  The Untold... Is one of the worst films I ever...
# 10120  __label__positive  This film starts out with a family who were al...
# 33160  __label__negative  I can't believe I am so angry after seeing thi...
# ...                  ...                                                ...
# 10442  __label__positive  This film struck me as a project that had a lo...
# 36589  __label__negative  Now, I won't deny that when I purchased this o...
# 16944  __label__positive  It's 1913. A studio prop boy spies the actress...
# 33406  __label__negative  I have been a fervent Hal Hartley supporter si...
# 20949  __label__positive  This is one of the movies one has to start wat...
# 178    __label__positive  The United States was still fighting World War...
# 8368   __label__positive  It's hard to imagine a director capable of suc...
# 32206  __label__negative  i think this one sucked on ice, because it lef...
# 47631  __label__negative  I'm only going to write more because it's requ...
# 14284  __label__positive  The whole shorthand for supposedly being more ...
# 45217  __label__negative  Edge Vs. Michaels-Boring in general (loved the...
# 27493  __label__negative  The premise was intriguing, but sadly this fil...
# 12187  __label__positive  If you delete the first twenty minutes or so o...
# 22018  __label__positive  If there's one theme of this film, it's that p...
# 43633  __label__negative  This is an Emperor's New Clothes situation. So...
# 12960  __label__positive  This was really a "nightmare" of a film; i saw...
# 39302  __label__negative  I appeared as an extra and was on location as ...
# 36116  __label__negative  I picked this movie up to replace the dismal c...
# 6328   __label__positive  This movie is an awesome non-stop laugh riot i...
# 17482  __label__positive  039: Anna Christie (1930) - released 2/21/1930...
# 13335  __label__positive  Three American lads are backpacking their way ...
# 27208  __label__negative  I really wanted to like The Pillow Book. Intri...
# 27711  __label__negative  This movie was seriously awful. The acting was...
# 22745  __label__positive  I always thought my father had a second life a...
# 1051   __label__positive  The movie was totally Awesome and Cool. The gr...
# 37602  __label__negative  If this is classed as 'real life' of London, t...
# 42731  __label__negative  Amnesiac women who remove their clothes at the...
# 18901  __label__positive  Frank Sinatra starred in this odd little short...
# 48276  __label__negative  Welcome to the Plan 9 From Outer Space of Star...
# 19797  __label__positive  I loved this. It starts out as a fairly normal...
#
# [35000 rows x 2 columns]

# %%
df_fast_test = pd.DataFrame({'label':y_test, 'review':X_test})
df_fast_test = df_fast_test.replace(1,'__label__positive')
df_fast_test = df_fast_test.replace(0,'__label__negative')

# %%
df_fast_test
# Out:
#                    label                                             review
# 40518  __label__negative  That's how I was when I walked (staggered) out...
# 43509  __label__negative  A true yawner and a bad film even for the Chan...
# 23419  __label__positive  A touching movie. It is full of emotions and w...
# 47043  __label__negative  A feminist tract in which if you the viewer be...
# 49474  __label__negative  I picked out this DVD out of the cheepo bin at...
# 4219   __label__positive  people claim its edited funny but they had to ...
# 92     __label__positive  I happened upon this film by accident, and rea...
# 21136  __label__positive  The first bottom movie was an absolute laugh f...
# 38411  __label__negative  We screened this movie in a club as an example...
# 31400  __label__negative  I remember watching this movie when I was youn...
# 44265  __label__negative  Can anyone give me a reason why only one Ameri...
# 21078  __label__positive  Woaww Is it only now that you notice the links...
# 42538  __label__negative  This is one of those movies that go out of pri...
# 3570   __label__positive  Okay, so Robbie's a little hokey-looking by to...
# 12376  __label__positive  More like psychological analysis of movies, bu...
# 32499  __label__negative  "They Are Among Us" is poor science fiction at...
# 5865   __label__positive  The summary line above, spoken by James Cloud ...
# 36823  __label__negative  I should explain why i gave this..."piece of a...
# 10683  __label__positive  What a delightful movie. The characters were n...
# 13338  __label__positive  Great movie. I was laughing all time through. ...
# 4300   __label__positive  I have watched this episode more often than an...
# 23461  __label__positive  After a decade of turbulent unrest, American m...
# 13219  __label__positive  While this movie is not the most entertaining ...
# 48141  __label__negative  This show is what happened to The Screen Saver...
# 29334  __label__negative  Where do they get the money to make films like...
# 27989  __label__negative  And that comes from someone that will withstan...
# 21900  __label__positive  When the movie "The Cure" starts, we find out ...
# 37242  __label__negative  I live in Salt Lake City and I'm not a Mormon,...
# 43344  __label__negative  "Wild Rebels" was probably a fun second film a...
# 3532   __label__positive  Well, for starters, this actually was THE most...
# ...                  ...                                                ...
# 6627   __label__positive  I don't understand why the reviews of this fil...
# 3837   __label__positive  SYNOPSIS The future as seen from 1939 England....
# 23853  __label__positive  It's simply ridiculous how underrated this mov...
# 34502  __label__negative  FLIGHT OF FURY takes the mantle of being the v...
# 30302  __label__negative  I couldn't wait to put this movie in my DVD pl...
# 17649  __label__positive  This is one of the Stooges best shorts. It was...
# 7241   __label__positive  The first time I had the window of opportunity...
# 21009  __label__positive  Don't watch this movie expecting the Jane Aust...
# 34420  __label__negative  Usually, I know after the first minute of a mo...
# 21710  __label__positive  Just got back from seeing Black Snake Moan. I ...
# 6374   __label__positive  It's not too bad a b movie, with Sanders, Barr...
# 37796  __label__negative  Thomas Edison had no other reason to make this...
# 14810  __label__positive  This was Eisenstein's first completed project ...
# 5560   __label__positive  Touching; Well directed autobiography of a tal...
# 14676  __label__positive  They Made Me a Criminal is a remake of an earl...
# 49947  __label__negative  Ill-conceived sequel(..the absurd idea of havi...
# 15312  __label__positive  But George and Gracie's are not among them. Th...
# 31198  __label__negative  The worst thing about Crush is not that it's a...
# 18455  __label__positive  Great characters, great acting, great dialogue...
# 24723  __label__positive  For readers who have already seen one of Miyaz...
# 27792  __label__negative  What do you call a horror story without horror...
# 27195  __label__negative  Power Rangers, the completely awful kid's show...
# 46005  __label__negative  This movie treads on very familiar ground -- t...
# 38643  __label__negative  "Season on the Brink" is one of my favorite bo...
# 7536   __label__positive  am i the only one who saw the connection betwe...
# 20245  __label__positive  This is such a revered and studied film, a cla...
# 22938  __label__positive  I had the PRIVILEGE of attending the UK premie...
# 38304  __label__negative  Why does this piece of film have so many ravin...
# 31037  __label__negative  This movie is so bad it's good -- in an uninte...
# 46210  __label__negative  one of the most awaited movie!i thought himesh...
#
# [15000 rows x 2 columns]

# %%
df_fast_train.to_csv('train.txt',sep=' ',index=False,header=False)
df_fast_test.to_csv('test.txt',sep=' ',index=False,header=False)

# %%
X_test.to_csv('test_fasttext.txt',sep=' ',index=False,header=False) # dump reviews without labels, used to test

# %%
from fastText import train_supervised
from fastText import load_model

# %%
model = train_supervised(
     input="train.txt",
     epoch=50,
     minCount=1,
     wordNgrams=2,
)

model.save_model("model.bin")

# %%
model = load_model("model.bin")

# %%
result = model.test("test.txt")
result
# Out:
# (15000, 0.8989333333333334, 0.8989333333333334)

# %%
y_true_fasttext = df_fast_test['label']

# %%
y_pred_fasttext = []

with open('test_fasttext.txt') as reviews:
    for review in reviews:
        y_pred_label, score = model.predict(review.strip('\n'))   
        y_pred_fasttext.append(y_pred_label[0])

# %%
# computer the metrics of fastText
print(classification_report(y_true_fasttext, y_pred_fasttext))
print('Accuracy: ',accuracy_score(y_true_fasttext, y_pred_fasttext))
# Out:
#                    precision    recall  f1-score   support
#
# __label__negative       0.91      0.89      0.90      7500
# __label__positive       0.89      0.91      0.90      7500
#
#       avg / total       0.90      0.90      0.90     15000
#
# Accuracy:  0.8989333333333334
